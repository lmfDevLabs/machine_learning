# %%
# predict.py
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model

def load_and_predict(input_csv, model_path, output_txt):
    # Carga el modelo
    model = load_model(model_path)

    # Carga los datos para predicción
    data = pd.read_csv(input_csv)
    X = data.values  # Asumiendo que 'data' ya está preprocesado adecuadamente

    # Realiza las predicciones
    predictions = model.predict(X)
    predicted_labels = (predictions > 0.5).astype(int)  # Asumiendo clasificación binaria

    # Guarda las predicciones en un archivo de texto
    np.savetxt(output_txt, predicted_labels, fmt='%d')

if __name__ == "__main__":
    input_csv = 'quiz.csv'  # El path al CSV de entrada
    model_path = 'best_model.h5'  # El path al modelo H5 guardado
    output_txt = 'answers.txt'  # El path al archivo de texto de salida
    load_and_predict(input_csv, model_path, output_txt)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-c955107d465d> in <cell line: 21>()
#      23     model_path = 'best_model.h5'  # El path al modelo H5 guardado
#      24     output_txt = 'answers.txt'  # El path al archivo de texto de salida
# ---> 25     load_and_predict(input_csv, model_path, output_txt)
#
# <ipython-input-1-c955107d465d> in load_and_predict(input_csv, model_path, output_txt)
#       6 def load_and_predict(input_csv, model_path, output_txt):
#       7     # Carga el modelo
# ----> 8     model = load_model(model_path)
#       9
#      10     # Carga los datos para predicción
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
# ...
